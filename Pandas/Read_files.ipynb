# %% [markdown]
# # Dependencies

# %%
import pandas as pd

# %% [markdown]
# # Csv File Handeling

# %%
df = pd.read_csv('bookdata.csv')
df
# Out:
#      availability        category  \
# 0              19           music
# 1              19        business
# 2              19     young adult
# 3              19          poetry
# 4              19  sequential art
# ..            ...             ...
# 995            14      nonfiction
# 996            15       childrens
# 997            15       biography
# 998            15         default
# 999            15   add a comment
#
#                                            description  no_of_reviews  \
# 0    Punk's raw power rejuvenated rock, but by the ...              0
# 1    Drawing on his extensive experience evaluating...              0
# 2    Patient Twenty-nine.A monster roams the halls ...              0
# 3    This book is an important and complete collect...              0
# 4    Scott Pilgrim's life is totally sweet. He's 23...              0
# ..                                                 ...            ...
# ...
